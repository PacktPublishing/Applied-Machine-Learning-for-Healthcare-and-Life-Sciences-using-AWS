# %%
# %%writefile script/train.py

from DeepPurpose import utils, CompoundPred
from tdc.single_pred import ADME
import warnings
import argparse
import os
warnings.filterwarnings("ignore")

if __name__ == "__main__":
    
    
    parser = argparse.ArgumentParser()
    parser.add_argument('--model_dir', type=str, default=os.environ['SM_MODEL_DIR'])
    parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAIN'))
    args = parser.parse_args()
    print ("*****training file*****")
    
    files = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(args.train):
        for file in f:
            files.append(os.path.join(r, file))

    for f in files:
        print(f)
        
    X, y = ADME(name = 'HIA_Hou').get_data(format = 'DeepPurpose')
    drug_encoding = 'MPNN'
    train, val, test = utils.data_process(X_drug = X, 
                                      y = y, 
                                      drug_encoding = drug_encoding,
                                      random_seed = 'TDC')
    config = utils.generate_config(drug_encoding = drug_encoding, 
                         train_epoch = 3, 
                         LR = 0.001, 
                         batch_size = 128,
                         mpnn_hidden_size = 32,
                         mpnn_depth = 2
                        )
    model = CompoundPred.model_initialize(**config)
    model.train(train, val, test)
    
    model.save_model(args.model_dir)
# Out:
# Overwriting script/train.py

# %%
# %%writefile Dockerfile
#
# # Part of the implementation of this container is based on the Amazon SageMaker Apache MXNet container.
# # https://github.com/aws/sagemaker-mxnet-container
#
# FROM ubuntu:16.04
#
# LABEL maintainer="Amazon AI"
#
# # Defining some variables used at build time to install Python3
# ARG PYTHON=python3
# ARG PYTHON_PIP=python3-pip
# ARG PIP=pip3
# ARG PYTHON_VERSION=3.6.6
#
# # Install some handful libraries like curl, wget, git, build-essential, zlib
# RUN apt-get update && apt-get install -y --no-install-recommends software-properties-common && \
#     add-apt-repository ppa:deadsnakes/ppa -y && \
#     apt-get update && apt-get install -y --no-install-recommends \
#         build-essential \
#         ca-certificates \
#         curl \
#         wget \
#         git \
#         libopencv-dev \
#         openssh-client \
#         openssh-server \
#         vim \
#         zlib1g-dev && \
#     rm -rf /var/lib/apt/lists/*
#
# # Installing Python3
# RUN wget https://www.python.org/ftp/python/$PYTHON_VERSION/Python-$PYTHON_VERSION.tgz && \
#         tar -xvf Python-$PYTHON_VERSION.tgz && cd Python-$PYTHON_VERSION && \
#         ./configure && make && make install && \
#         apt-get update && apt-get install -y --no-install-recommends libreadline-gplv2-dev libncursesw5-dev libssl-dev libsqlite3-dev tk-dev libgdbm-dev libc6-dev libbz2-dev && \
#         make && make install && rm -rf ../Python-$PYTHON_VERSION* && \
#         ln -s /usr/local/bin/pip3 /usr/bin/pip
#
# # Upgrading pip and creating symbolic link for python3
# RUN ${PIP} --no-cache-dir install --upgrade pip
# RUN ln -s $(which ${PYTHON}) /usr/local/bin/python
#
# WORKDIR /
#
# # Installing numpy, pandas, scikit-learn, scipy
# RUN ${PIP} install --no-cache --upgrade \
#         numpy==1.14.5 \
#         pandas==0.24.1 \
#         scikit-learn==0.20.3 \
#         requests==2.21.0 \
#         scipy==1.2.2
#
# # Setting some environment variables.
# ENV PYTHONDONTWRITEBYTECODE=1 \
#     PYTHONUNBUFFERED=1 \
#     LD_LIBRARY_PATH="${LD_LIBRARY_PATH}:/usr/local/lib" \
#     PYTHONIOENCODING=UTF-8 \
#     LANG=C.UTF-8 \
#     LC_ALL=C.UTF-8
#
# RUN ${PIP} install --no-cache --upgrade \
#     sagemaker-training
#
#
# RUN pip install rdkit-pypi
# RUN pip install PyTDC
# RUN pip install pandas-flavor
# RUN pip install git+https://github.com/bp-kelley/descriptastorus
# RUN pip install DeepPurpose
#
# # Copies code under /opt/ml/code where sagemaker-containers expects to find the script to run
# COPY script/train.py /opt/ml/code/train.py
#
# # Defines train.py as script entry point
# ENV SAGEMAKER_PROGRAM train.py
# Out:
# Overwriting Dockerfile

# %%
# %%sh
#
# docker_name=sagemaker-deeppurpose
# docker build -t $docker_name -f Dockerfile .
#
# account=$(aws sts get-caller-identity --query Account --output text)
# echo $account
# region=$(aws configure get region)
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${docker_name}:latest"
# # If the repository doesn't exist in ECR, create it.
# aws ecr describe-repositories --repository-names "${docker_name}" > /dev/null 2>&1
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${docker_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# $(aws ecr get-login --region ${region} --no-include-email)
#
# docker tag ${docker_name} ${fullname}
# docker push ${fullname}
# Out:
# Step 1/21 : FROM ubuntu:16.04
#  ---> b6f507652425
# Step 2/21 : LABEL maintainer="Amazon AI"
#  ---> Using cache
#  ---> 7d3810176a2e
# Step 3/21 : ARG PYTHON=python3
#  ---> Using cache
#  ---> 683c419be179
# Step 4/21 : ARG PYTHON_PIP=python3-pip
#  ---> Using cache
#  ---> b8624329a0e4
# Step 5/21 : ARG PIP=pip3
#  ---> Using cache
#  ---> a42942582dae
# Step 6/21 : ARG PYTHON_VERSION=3.6.6
#  ---> Using cache
#  ---> 1a0cabeefc40
# Step 7/21 : RUN apt-get update && apt-get install -y --no-install-recommends software-properties-common &&     add-apt-repository ppa:deadsnakes/ppa -y &&     apt-get update && apt-get install -y --no-install-recommends         build-essential         ca-certificates         curl         wget         git         libopencv-dev         openssh-client         openssh-server         vim         zlib1g-dev &&     rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> 0ea7cc8cd8de
# Step 8/21 : RUN wget https://www.python.org/ftp/python/$PYTHON_VERSION/Python-$PYTHON_VERSION.tgz &&         tar -xvf Python-$PYTHON_VERSION.tgz && cd Python-$PYTHON_VERSION &&         ./configure && make && make install &&         apt-get update && apt-get install -y --no-install-recommends libreadline-gplv2-dev libncursesw5-dev libssl-dev libsqlite3-dev tk-dev libgdbm-dev libc6-dev libbz2-dev &&         make && make install && rm -rf ../Python-$PYTHON_VERSION* &&         ln -s /usr/local/bin/pip3 /usr/bin/pip
#  ---> Using cache
#  ---> b450e47d8d2d
# Step 9/21 : RUN ${PIP} --no-cache-dir install --upgrade pip
#  ---> Using cache
#  ---> b0a2025ce6a2
# Step 10/21 : RUN ln -s $(which ${PYTHON}) /usr/local/bin/python
#  ---> Using cache
#  ---> 9c4fad68a881
# Step 11/21 : WORKDIR /
#  ---> Using cache
#  ---> 070aa53b9089
# Step 12/21 : RUN ${PIP} install --no-cache --upgrade         numpy==1.14.5         pandas==0.24.1         scikit-learn==0.20.3         requests==2.21.0         scipy==1.2.2
#  ---> Using cache
#  ---> 91a41f03098f
# Step 13/21 : ENV PYTHONDONTWRITEBYTECODE=1     PYTHONUNBUFFERED=1     LD_LIBRARY_PATH="${LD_LIBRARY_PATH}:/usr/local/lib"     PYTHONIOENCODING=UTF-8     LANG=C.UTF-8     LC_ALL=C.UTF-8
#  ---> Using cache
#  ---> fbeb9c5dc1db
# Step 14/21 : RUN ${PIP} install --no-cache --upgrade     sagemaker-training
#  ---> Using cache
#  ---> 2d16ebb44773
# Step 15/21 : RUN pip install rdkit-pypi
#  ---> Using cache
#  ---> 18c273648289
# Step 16/21 : RUN pip install PyTDC
#  ---> Using cache
#  ---> f1e3c3f4a451
# Step 17/21 : RUN pip install pandas-flavor
#  ---> Using cache
#  ---> 8ada73586f01
# Step 18/21 : RUN pip install git+https://github.com/bp-kelley/descriptastorus
#  ---> Using cache
#  ---> 824e428ab888
# Step 19/21 : RUN pip install DeepPurpose
#  ---> Using cache
#  ---> 833a704dfe46
# Step 20/21 : COPY script/train.py /opt/ml/code/train.py
#  ---> 5e6b9b869035
# Step 21/21 : ENV SAGEMAKER_PROGRAM train.py
#  ---> Running in 576dfc6ac3fc
# Removing intermediate container 576dfc6ac3fc
#  ---> cdd660ee498d
# Successfully built cdd660ee498d
# Successfully tagged sagemaker-deeppurpose:latest
# 485822383573
# Login Succeeded
# The push refers to repository [485822383573.dkr.ecr.us-east-1.amazonaws.com/sagemaker-deeppurpose]
# 5ea1591e4a68: Preparing
# 5b8b92537490: Preparing
# 3f28340b79bf: Preparing
# ab7aa6aea974: Preparing
# e5b8e6147aa8: Preparing
# e402ab955752: Preparing
# 7b86cdf37e7d: Preparing
# a8921e0e27bf: Preparing
# 4fe9a064275d: Preparing
# 908ed4810566: Preparing
# ead85a8639fc: Preparing
# ddc7b974cfa7: Preparing
# 1251204ef8fc: Preparing
# 47ef83afae74: Preparing
# df54c846128d: Preparing
# be96a3f634de: Preparing
# e402ab955752: Waiting
# 7b86cdf37e7d: Waiting
# a8921e0e27bf: Waiting
# 4fe9a064275d: Waiting
# 908ed4810566: Waiting
# ead85a8639fc: Waiting
# ddc7b974cfa7: Waiting
# 1251204ef8fc: Waiting
# 47ef83afae74: Waiting
# df54c846128d: Waiting
# be96a3f634de: Waiting
# ab7aa6aea974: Layer already exists
# 5b8b92537490: Layer already exists
# 3f28340b79bf: Layer already exists
# e5b8e6147aa8: Layer already exists
# e402ab955752: Layer already exists
# 7b86cdf37e7d: Layer already exists
# a8921e0e27bf: Layer already exists
# 4fe9a064275d: Layer already exists
# 908ed4810566: Layer already exists
# ead85a8639fc: Layer already exists
# ddc7b974cfa7: Layer already exists
# 1251204ef8fc: Layer already exists
# 47ef83afae74: Layer already exists
# df54c846128d: Layer already exists
# be96a3f634de: Layer already exists
# 5ea1591e4a68: Pushed
# latest: digest: sha256:3ecd37dafd86eb5d6ba2342b47362b0aa34422d6c3ee09d417417a293d845c36 size: 3683
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.session import Session

# Setup session
sess = sagemaker.Session()

# S3 bucket for saving code and model artifacts.
# Feel free to specify a different bucket here if you wish.
bucket = sess.default_bucket()

# # Location to put your custom code.
# custom_code_upload_location = "deeppurpose/customcode"

# IAM execution role that gives Amazon SageMaker access to resources in your AWS account.
# You can use the Amazon SageMaker Python SDK to get the role from the notebook environment.
role = get_execution_role()

# %%
import boto3

from sagemaker.local import LocalSession
sagemaker_session = LocalSession()

# Set target dgl-docker name
docker_name = "sagemaker-deeppurpose"

CODE_PATH = "script/train.py"
code_location = sess.upload_data(CODE_PATH, bucket=bucket, key_prefix=custom_code_upload_location)

account = sess.boto_session.client("sts").get_caller_identity()["Account"]
region = sess.boto_session.region_name
image = "{}.dkr.ecr.{}.amazonaws.com/{}:latest".format(account, region, docker_name)
print(image)
task_tags = [{"Key": "ML Task", "Value": "deeppurpose"}]
estimator = sagemaker.estimator.Estimator(
    image,
    role,
    instance_count=1,
    instance_type="local",
    tags=task_tags,
    sagemaker_session=sagemaker_session,
    #hyperparameters={"sagemaker_program": "train.py", "sagemaker_submit_directory": code_location}
)
# Out:
# 485822383573.dkr.ecr.us-east-1.amazonaws.com/sagemaker-deeppurpose:latest

# %%
train_prefix='deeppurpose/data'
train_data=sess.upload_data('DeepPurpose-master/toy_data/AID1706.txt', bucket=bucket, key_prefix='deeppurpose/data')
print(train_data)


# train_config=sagemaker.session.s3_input(
#     train_data, content_type="text/csv"
# )
estimator.fit({"train":train_data})
# Out:
# s3://sagemaker-us-east-1-485822383573/deeppurpose/data/AID1706.txt
# Creating dzj1jounl0-algo-1-jzngf ...
# Creating dzj1jounl0-algo-1-jzngf ... done
# Attaching to dzj1jounl0-algo-1-jzngf
# dzj1jounl0-algo-1-jzngf | /usr/local/lib/python3.6/site-packages/paramiko/transport.py:33: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography and will be removed in a future release.
# dzj1jounl0-algo-1-jzngf |   from cryptography.hazmat.backends import default_backend
# dzj1jounl0-algo-1-jzngf | 2022-07-21 00:33:25,787 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# dzj1jounl0-algo-1-jzngf | 2022-07-21 00:33:25,800 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# dzj1jounl0-algo-1-jzngf | 2022-07-21 00:33:25,805 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# dzj1jounl0-algo-1-jzngf | 2022-07-21 00:33:25,818 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# dzj1jounl0-algo-1-jzngf | 2022-07-21 00:33:25,821 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# dzj1jounl0-algo-1-jzngf | 2022-07-21 00:33:25,834 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# dzj1jounl0-algo-1-jzngf | 2022-07-21 00:33:25,835 sagemaker-training-toolkit INFO     Invoking user script
# dzj1jounl0-algo-1-jzngf |
# dzj1jounl0-algo-1-jzngf | Training Env:
# dzj1jounl0-algo-1-jzngf |
# dzj1jounl0-algo-1-jzngf | {
# dzj1jounl0-algo-1-jzngf |     "additional_framework_parameters": {},
# dzj1jounl0-algo-1-jzngf |     "channel_input_dirs": {
# dzj1jounl0-algo-1-jzngf |         "train": "/opt/ml/input/data/train"
# dzj1jounl0-algo-1-jzngf |     },
# dzj1jounl0-algo-1-jzngf |     "current_host": "algo-1-jzngf",
# dzj1jounl0-algo-1-jzngf |     "current_instance_group": "homogeneousCluster",
# dzj1jounl0-algo-1-jzngf |     "current_instance_group_hosts": [],
# dzj1jounl0-algo-1-jzngf |     "current_instance_type": "local",
# dzj1jounl0-algo-1-jzngf |     "distribution_hosts": [
# dzj1jounl0-algo-1-jzngf |         "algo-1-jzngf"
# dzj1jounl0-algo-1-jzngf |     ],
# dzj1jounl0-algo-1-jzngf |     "distribution_instance_groups": [],
# dzj1jounl0-algo-1-jzngf |     "framework_module": null,
# dzj1jounl0-algo-1-jzngf |     "hosts": [
# dzj1jounl0-algo-1-jzngf |         "algo-1-jzngf"
# dzj1jounl0-algo-1-jzngf |     ],
# dzj1jounl0-algo-1-jzngf |     "hyperparameters": {},
# dzj1jounl0-algo-1-jzngf |     "input_config_dir": "/opt/ml/input/config",
# dzj1jounl0-algo-1-jzngf |     "input_data_config": {
# dzj1jounl0-algo-1-jzngf |         "train": {
# dzj1jounl0-algo-1-jzngf |             "TrainingInputMode": "File"
# dzj1jounl0-algo-1-jzngf |         }
# dzj1jounl0-algo-1-jzngf |     },
# dzj1jounl0-algo-1-jzngf |     "input_dir": "/opt/ml/input",
# dzj1jounl0-algo-1-jzngf |     "instance_groups": [],
# dzj1jounl0-algo-1-jzngf |     "instance_groups_dict": {},
# dzj1jounl0-algo-1-jzngf |     "is_hetero": false,
# dzj1jounl0-algo-1-jzngf |     "is_master": true,
# dzj1jounl0-algo-1-jzngf |     "is_modelparallel_enabled": null,
# dzj1jounl0-algo-1-jzngf |     "job_name": "sagemaker-deeppurpose-2022-07-21-00-33-22-612",
# dzj1jounl0-algo-1-jzngf |     "log_level": 20,
# dzj1jounl0-algo-1-jzngf |     "master_hostname": "algo-1-jzngf",
# dzj1jounl0-algo-1-jzngf |     "model_dir": "/opt/ml/model",
# dzj1jounl0-algo-1-jzngf |     "module_dir": "/opt/ml/code",
# dzj1jounl0-algo-1-jzngf |     "module_name": "train",
# dzj1jounl0-algo-1-jzngf |     "network_interface_name": "eth0",
# dzj1jounl0-algo-1-jzngf |     "num_cpus": 4,
# dzj1jounl0-algo-1-jzngf |     "num_gpus": 0,
# dzj1jounl0-algo-1-jzngf |     "output_data_dir": "/opt/ml/output/data",
# dzj1jounl0-algo-1-jzngf |     "output_dir": "/opt/ml/output",
# dzj1jounl0-algo-1-jzngf |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# dzj1jounl0-algo-1-jzngf |     "resource_config": {
# dzj1jounl0-algo-1-jzngf |         "current_host": "algo-1-jzngf",
# dzj1jounl0-algo-1-jzngf |         "hosts": [
# dzj1jounl0-algo-1-jzngf |             "algo-1-jzngf"
# dzj1jounl0-algo-1-jzngf |         ]
# dzj1jounl0-algo-1-jzngf |     },
# dzj1jounl0-algo-1-jzngf |     "user_entry_point": "train.py"
# dzj1jounl0-algo-1-jzngf | }
# dzj1jounl0-algo-1-jzngf |
# dzj1jounl0-algo-1-jzngf | Environment variables:
# dzj1jounl0-algo-1-jzngf |
# dzj1jounl0-algo-1-jzngf | SM_HOSTS=["algo-1-jzngf"]
# dzj1jounl0-algo-1-jzngf | SM_NETWORK_INTERFACE_NAME=eth0
# dzj1jounl0-algo-1-jzngf | SM_HPS={}
# dzj1jounl0-algo-1-jzngf | SM_USER_ENTRY_POINT=train.py
# dzj1jounl0-algo-1-jzngf | SM_FRAMEWORK_PARAMS={}
# dzj1jounl0-algo-1-jzngf | SM_RESOURCE_CONFIG={"current_host":"algo-1-jzngf","hosts":["algo-1-jzngf"]}
# dzj1jounl0-algo-1-jzngf | SM_INPUT_DATA_CONFIG={"train":{"TrainingInputMode":"File"}}
# dzj1jounl0-algo-1-jzngf | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# dzj1jounl0-algo-1-jzngf | SM_CHANNELS=["train"]
# dzj1jounl0-algo-1-jzngf | SM_CURRENT_HOST=algo-1-jzngf
# dzj1jounl0-algo-1-jzngf | SM_CURRENT_INSTANCE_TYPE=local
# dzj1jounl0-algo-1-jzngf | SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# dzj1jounl0-algo-1-jzngf | SM_CURRENT_INSTANCE_GROUP_HOSTS=[]
# dzj1jounl0-algo-1-jzngf | SM_INSTANCE_GROUPS=[]
# dzj1jounl0-algo-1-jzngf | SM_INSTANCE_GROUPS_DICT={}
# dzj1jounl0-algo-1-jzngf | SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# dzj1jounl0-algo-1-jzngf | SM_IS_HETERO=false
# dzj1jounl0-algo-1-jzngf | SM_MODULE_NAME=train
# dzj1jounl0-algo-1-jzngf | SM_LOG_LEVEL=20
# dzj1jounl0-algo-1-jzngf | SM_FRAMEWORK_MODULE=
# dzj1jounl0-algo-1-jzngf | SM_INPUT_DIR=/opt/ml/input
# dzj1jounl0-algo-1-jzngf | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# dzj1jounl0-algo-1-jzngf | SM_OUTPUT_DIR=/opt/ml/output
# dzj1jounl0-algo-1-jzngf | SM_NUM_CPUS=4
# dzj1jounl0-algo-1-jzngf | SM_NUM_GPUS=0
# dzj1jounl0-algo-1-jzngf | SM_MODEL_DIR=/opt/ml/model
# dzj1jounl0-algo-1-jzngf | SM_MODULE_DIR=/opt/ml/code
# dzj1jounl0-algo-1-jzngf | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1-jzngf","current_instance_group":"homogeneousCluster","current_instance_group_hosts":[],"current_instance_type":"local","distribution_hosts":["algo-1-jzngf"],"distribution_instance_groups":[],"framework_module":null,"hosts":["algo-1-jzngf"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":[],"instance_groups_dict":{},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"job_name":"sagemaker-deeppurpose-2022-07-21-00-33-22-612","log_level":20,"master_hostname":"algo-1-jzngf","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-jzngf","hosts":["algo-1-jzngf"]},"user_entry_point":"train.py"}
# dzj1jounl0-algo-1-jzngf | SM_USER_ARGS=[]
# dzj1jounl0-algo-1-jzngf | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# dzj1jounl0-algo-1-jzngf | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# dzj1jounl0-algo-1-jzngf | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
# dzj1jounl0-algo-1-jzngf |
# dzj1jounl0-algo-1-jzngf | Invoking script with the following command:
# dzj1jounl0-algo-1-jzngf |
# dzj1jounl0-algo-1-jzngf | /usr/local/bin/python3.6 train.py
# dzj1jounl0-algo-1-jzngf |
# dzj1jounl0-algo-1-jzngf |
# dzj1jounl0-algo-1-jzngf | WARNING:root:No normalization for BCUT2D_MWHI
# dzj1jounl0-algo-1-jzngf | WARNING:root:No normalization for BCUT2D_MWLOW
# dzj1jounl0-algo-1-jzngf | WARNING:root:No normalization for BCUT2D_CHGHI
# dzj1jounl0-algo-1-jzngf | WARNING:root:No normalization for BCUT2D_CHGLO
# dzj1jounl0-algo-1-jzngf | WARNING:root:No normalization for BCUT2D_LOGPHI
# dzj1jounl0-algo-1-jzngf | WARNING:root:No normalization for BCUT2D_LOGPLOW
# dzj1jounl0-algo-1-jzngf | WARNING:root:No normalization for BCUT2D_MRHI
# dzj1jounl0-algo-1-jzngf | WARNING:root:No normalization for BCUT2D_MRLOW
# dzj1jounl0-algo-1-jzngf | *****training file*****
# dzj1jounl0-algo-1-jzngf | /opt/ml/input/data/train/AID1706.txt
# dzj1jounl0-algo-1-jzngf | Downloading...
# 100% 40.1k/40.1k [00:00<00:00, 1.07MiB/s]
# dzj1jounl0-algo-1-jzngf | Loading...
# dzj1jounl0-algo-1-jzngf | Done!
# dzj1jounl0-algo-1-jzngf | Drug Property Prediction Mode...
# dzj1jounl0-algo-1-jzngf | in total: 578 drugs
# dzj1jounl0-algo-1-jzngf | encoding drug...
# dzj1jounl0-algo-1-jzngf | unique drugs: 578
# dzj1jounl0-algo-1-jzngf | Done.
# dzj1jounl0-algo-1-jzngf | Let's use CPU/s!
# dzj1jounl0-algo-1-jzngf | --- Data Preparation ---
# dzj1jounl0-algo-1-jzngf | --- Go for Training ---
# dzj1jounl0-algo-1-jzngf | Training at Epoch 1 iteration 0 with loss 0.68279. Total time 0.0 hours
# dzj1jounl0-algo-1-jzngf | Validation at Epoch 1 , AUROC: 0.56862 , AUPRC: 0.88669 , F1: 0.93577
# dzj1jounl0-algo-1-jzngf | Training at Epoch 2 iteration 0 with loss 0.36297. Total time 0.00027 hours
# dzj1jounl0-algo-1-jzngf | Validation at Epoch 2 , AUROC: 0.57703 , AUPRC: 0.91602 , F1: 0.93577
# dzj1jounl0-algo-1-jzngf | Training at Epoch 3 iteration 0 with loss 0.46316. Total time 0.00027 hours
# dzj1jounl0-algo-1-jzngf | Validation at Epoch 3 , AUROC: 0.57142 , AUPRC: 0.91321 , F1: 0.93577
# dzj1jounl0-algo-1-jzngf | --- Go for Testing ---
# dzj1jounl0-algo-1-jzngf | Testing AUROC: 0.49834983498349833 , AUPRC: 0.8729811519617816 , F1: 0.9308755760368664
# dzj1jounl0-algo-1-jzngf | --- Training Finished ---
# dzj1jounl0-algo-1-jzngf | 2022-07-21 00:33:34,374 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# dzj1jounl0-algo-1-jzngf exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
