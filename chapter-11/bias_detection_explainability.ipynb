# %% [markdown]
# ### Bias Detection and Explanability in Healthcare Coverage Amounts
# This exercise is part of *Chapter 11* in the book *Applied Machine Learning for Healthcare and Life Sciences Using AWS*. Make sure you have completed the steps as outlined in the *Technical requirements* section of *Chapter 11* to successfully complete this exercise. Also, make sure you have downloaded the dataset created the data folder as described in the *Aquiring the dataset* subsection under the *Detecting bias and explaining model predictions for healthcare coverage amounts* section.
#
# In this notebook, we will use SageMaker Clarify to create bias metrics for our training data and also our model. We will also generate explanability metrics for our model to gather feature importance for our model.
#
# **Note**: Parts of this notebook reference the following link: https://sagemaker-examples.readthedocs.io/en/latest/sagemaker_processing/fairness_and_explainability/fairness_and_explainability.html

# %% [markdown]
# Let's start by importing the required libraries and setting some environment variables.

# %%
from sagemaker import Session
from sagemaker import get_execution_role
import pandas as pd
import numpy as np
import os
import boto3
from datetime import date

session = Session()
bucket = session.default_bucket()
prefix = "chapter11"
region = session.boto_region_name
role = get_execution_role()
s3_client = boto3.client("s3")

# %% [markdown]
# Next, we will read the `patients.csv` file into a dataframe and examine its contents.

# %%
raw_data=pd.read_csv('data/patients.csv')

# %%
raw_data.head()
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  1d604da9-9a81-4ba9-80c2-de3375d59b40  1989-05-25       NaN  999-76-6866
# 1  034e9e3b-2def-4559-bb2a-7850888ae060  1983-11-14       NaN  999-73-5361
# 2  10339b10-3cd1-4ac3-ac13-ec26728cb592  1992-06-02       NaN  999-27-3385
# 3  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  1978-05-27       NaN  999-85-4926
# 4  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a  1996-10-18       NaN  999-60-7372
#
#      DRIVERS    PASSPORT PREFIX            FIRST           LAST SUFFIX  ...  \
# 0  S99984236  X19277260X    Mr.  José Eduardo181       Gómez206    NaN  ...
# 1  S99962402  X88275464X    Mr.          Milo271        Feil794    NaN  ...
# 2  S99972682  X73754411X    Mr.        Jayson808       Fadel536    NaN  ...
# 3  S99974448  X40915583X   Mrs.       Mariana775  Rutherford999    NaN  ...
# 4  S99915787  X86772962X    Mr.      Gregorio366         Auer97    NaN  ...
#
#                          BIRTHPLACE                         ADDRESS  \
# 0  Marigot  Saint Andrew Parish  DM      427 Balistreri Way Unit 19
# 1        Danvers  Massachusetts  US        422 Farrell Path Unit 69
# 2    Springfield  Massachusetts  US       1056 Harris Lane Suite 70
# 3       Yarmouth  Massachusetts  US                  999 Kuhn Forge
# 4                Patras  Achaea  GR  1050 Lindgren Extension Apt 38
#
#          CITY          STATE            COUNTY     ZIP        LAT        LON  \
# 0    Chicopee  Massachusetts    Hampden County  1013.0  42.228354 -72.562951
# 1  Somerville  Massachusetts  Middlesex County  2143.0  42.360697 -71.126531
# 2    Chicopee  Massachusetts    Hampden County  1020.0  42.181642 -72.608842
# 3      Lowell  Massachusetts  Middlesex County  1851.0  42.636143 -71.343255
# 4      Boston  Massachusetts    Suffolk County  2135.0  42.352434 -71.028610
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE
# 0           271227.08             1334.88
# 1           793946.01             3204.49
# 2           574111.90             2606.40
# 3           935630.30             8756.19
# 4           598763.07             3772.20
#
# [5 rows x 25 columns]

# %% [markdown]
# We will now do some transformations with the data:
# 1. Use the `BIRTHDATE` column to calculate the age and categorize patients into different agegroups like Infant, Toddler, Kid, Teen, Adult and Old.
# 2. Calculate `COVERAGETOEXPENSERATIO` by dividing `HEALTHCARE_COVERAGE` by `HEALTHCARE_EXPENSES`.
# 3. Create a new binary `TARGET` variable that has the value `False` if the `COVERAGETOEXPENSERATIO` is `<=0.01`, otherwise it is `True`.
#
# Essentialy, we want to find patients who have less than 1% coverage for their healthcare expenses.

# %%
def calculateage(dob):
    today = date.today()
    return today.year - dob.year - ((today.month, 
                                      today.day) < (dob.month, 
                                                    dob.day))

# %%
raw_data['BIRTHDATE'] = pd.to_datetime(raw_data['BIRTHDATE'])
raw_data=raw_data[raw_data['DEATHDATE'].isna()]
raw_data['AGE'] = raw_data['BIRTHDATE'].apply(calculateage)
raw_data['COVERAGETOEXPENSERATIO'] = raw_data['HEALTHCARE_COVERAGE']/raw_data['HEALTHCARE_EXPENSES']
labels = ['Infant','Toddler','Kid','Teen', 'Adult', 'Old']
raw_data['AGEGROUPS'] = pd.cut(raw_data['AGE'], labels=labels, bins=[0, 3, 7, 12, 21, 65, np.inf])
raw_data['Target'] = raw_data['COVERAGETOEXPENSERATIO'].apply(lambda x: 'False' if x <= 0.01 else 'True')

# %% [markdown]
# Next, we sellect `CITY`, `COUNTY` and `AGEGROUPS` columns as our features and `TARGET` column as our target. Since the `TARGET` has `True` and `False` values, we model this as a binary classification problem.

# %%
X=raw_data[['CITY','COUNTY','AGEGROUPS']]
y=raw_data[['Target']]

# %% [markdown]
# We can now divide our patient population into train and test. We will use Label Encoder to encode our categorical columns into numerical values.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn import preprocessing
enc = preprocessing.LabelEncoder()
X_train=X_train.apply(enc.fit_transform)
X_test=X_test.apply(enc.fit_transform)
y_train=y_train.apply(enc.fit_transform)
y_test=y_test.apply(enc.fit_transform)

# %% [markdown]
# To train a model on SageMaker, we need to have the first column of our training data as the target variable. This also needs to be removed from the test dataset. We will do this in the next code section and save the files as CSVs.

# %%
X_train.insert(0, 'Target', y_train['Target'])
X_train.to_csv("data/train.csv", index=False, header=False)

# %%
X_test.to_csv("data/test.csv", index=False, header=False)

# %% [markdown]
# Next, let's upload the files on S3, as shown in the following code.

# %%
from sagemaker.s3 import S3Uploader
from sagemaker.inputs import TrainingInput

train_uri = S3Uploader.upload("data/train.csv", "s3://{}/{}".format(bucket, prefix))
train_input = TrainingInput(train_uri, content_type="csv")
test_uri = S3Uploader.upload("data/test.csv", "s3://{}/{}".format(bucket, prefix))

# %% [markdown]
# We are now ready to run our model training on SageMaker. We choose the SageMaker `xgboost` container to run our training.

# %%
from sagemaker.image_uris import retrieve
from sagemaker.estimator import Estimator

container = retrieve("xgboost", region, version="1.2-1")
xgb = Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    disable_profiler=True,
    sagemaker_session=session,
)

xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    objective="binary:logistic",
    num_round=800,
)

xgb.fit({"train": train_input}, logs=False)
# Out:
# 2022-11-04 23:35:58 Starting - Starting the training job...
# 2022-11-04 23:36:15 Starting - Preparing the instances for training...........
# 2022-11-04 23:37:17 Downloading - Downloading input data.....
# 2022-11-04 23:37:47 Training - Downloading the training image.........
# 2022-11-04 23:38:38 Training - Training image download completed. Training in progress..
# 2022-11-04 23:38:48 Uploading - Uploading generated training model.
# 2022-11-04 23:38:59 Completed - Training job completed

# %% [markdown]
# Once the training completes, we can create a model artifact from the estimator used in the training job.

# %%
model_name = "xgb-model-{}".format(datetime.now().strftime("%d-%m-%Y-%H-%M-%S"))
model = xgb.create_model(name=model_name)
container_def = model.prepare_container_def()
session.create_model(model_name, role, container_def)
# Out:
# 'xgb-model-04-11-2022-23-38-59'

# %% [markdown]
# We now have all the prerequisites for running SageMaker Clarify. We begin by defining a SageMaker Clarify processor.

# %%
from sagemaker import clarify

clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role, instance_count=1, instance_type="ml.m5.xlarge", sagemaker_session=session
)

# %% [markdown]
# Next, we define configurations for our data and model bias metrics.

# %%
bias_report_output_path = "s3://{}/{}/clarify-bias".format(bucket, prefix)
bias_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=bias_report_output_path,
    label="Target",
    headers=X_train.columns.to_list(),
    dataset_type="text/csv",
)

# %%
model_config = clarify.ModelConfig(
    model_name=model_name,
    instance_type="ml.m5.xlarge",
    instance_count=1,
    accept_type="text/csv",
    content_type="text/csv",
)

# %% [markdown]
# We try to create a bias report for our feature `AGEGROUP` and try to analyze the bias that feature has in each `CITY`. We also define a prediction probability threshold for our model predictions.

# %%
predictions_config = clarify.ModelPredictedLabelConfig(probability_threshold=0.8)

# %%
bias_config = clarify.BiasConfig(
    label_values_or_threshold=[1], facet_name="AGEGROUPS", group_name="CITY"
)

# %% [markdown]
# The following code runs the SageMaker Clarify bias report processor.

# %%
clarify_processor.run_bias(
    data_config=bias_data_config,
    bias_config=bias_config,
    model_config=model_config,
    model_predicted_label_config=predictions_config,
    pre_training_methods="all",
    post_training_methods="all",
)
# Out:
# Job Name:  Clarify-Bias-2022-11-04-23-39-00-817
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-068232277654/chapter11/train.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-068232277654/chapter11/clarify-bias/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-us-east-1-068232277654/chapter11/clarify-bias', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ...............................2022-11-04 23:44:02,641 logging.conf not found when configuring logging, using default logging configuration.
# 2022-11-04 23:44:02,642 Starting SageMaker Clarify Processing job
# 2022-11-04 23:44:02,642 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-11-04 23:44:02,642 Analysis result path: /opt/ml/processing/output
# 2022-11-04 23:44:02,642 This host is algo-1.
# 2022-11-04 23:44:02,643 This host is the leader.
# 2022-11-04 23:44:02,643 Number of hosts in the cluster is 1.
# 2022-11-04 23:44:02,946 Running Python / Pandas based analyzer.
# 2022-11-04 23:44:02,947 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2022-11-04 23:44:02,951 Loading dataset...
# /usr/local/lib/python3.9/site-packages/analyzer/data_loading/csv_data_loader.py:311: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_tmp, ignore_index=True)
# 2022-11-04 23:44:02,959 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CITY       800 non-null    int64
#  1   COUNTY     800 non-null    int64
#  2   AGEGROUPS  800 non-null    int64
# dtypes: int64(3)
# memory usage: 18.9 KB
# 2022-11-04 23:44:03,016 Spinning up shadow endpoint
# 2022-11-04 23:44:03,016 Creating endpoint-config with name sm-clarify-config-1667605443-8fb9
# 2022-11-04 23:44:03,195 Creating endpoint: 'sm-clarify-xgb-model-04-11-2022-23-38-59-1667605443-32d4'
# 2022-11-04 23:44:03,681 Using endpoint name: sm-clarify-xgb-model-04-11-2022-23-38-59-1667605443-32d4
# 2022-11-04 23:44:03,681 Waiting for endpoint ...
# 2022-11-04 23:44:03,681 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-11-04 23:47:04,161 Endpoint is in service after 180 seconds
# 2022-11-04 23:47:04,161 Endpoint ready.
# 2022-11-04 23:47:04,161 ======================================
# 2022-11-04 23:47:04,161 Calculating post-training bias metrics
# 2022-11-04 23:47:04,161 ======================================
# 2022-11-04 23:47:04,161 Getting predictions from the endpoint
# 2022-11-04 23:47:04,421 We assume a prediction above 0.800 indicates 1 and below or equal indicates 0.
# 2022-11-04 23:47:04,422 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-11-04 23:47:04,424 Column AGEGROUPS with data uniqueness fraction 0.0075 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:469: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2022-11-04 23:47:04,425 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-11-04 23:47:04,427 Column None with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-11-04 23:47:06,140 Calculated global analysis with predictor
# 2022-11-04 23:47:06,140 Stop using endpoint: sm-clarify-xgb-model-04-11-2022-23-38-59-1667605443-32d4
# 2022-11-04 23:47:06,140 Deleting endpoint configuration with name: sm-clarify-config-1667605443-8fb9
# 2022-11-04 23:47:06,259 Deleting endpoint with name: sm-clarify-xgb-model-04-11-2022-23-38-59-1667605443-32d4
# 2022-11-04 23:47:06,360 Model endpoint delivered 1.01038 requests per second and a total of 2 requests over 2 seconds
# 2022-11-04 23:47:06,360 =====================================
# 2022-11-04 23:47:06,360 Calculating pre-training bias metrics
# 2022-11-04 23:47:06,360 =====================================
# 2022-11-04 23:47:06,360 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-11-04 23:47:06,362 Column AGEGROUPS with data uniqueness fraction 0.0075 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:469: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2022-11-04 23:47:06,363 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-11-04 23:47:08,059 ======================================
# 2022-11-04 23:47:08,059 Calculating bias statistics for report
# 2022-11-04 23:47:08,059 ======================================
# 2022-11-04 23:47:08,059 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-11-04 23:47:08,061 Column AGEGROUPS with data uniqueness fraction 0.0075 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:469: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2022-11-04 23:47:08,062 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-11-04 23:47:08,064 Column None with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-11-04 23:47:08,074 Calculated global analysis without predictor
# 2022-11-04 23:47:08,074 Stop using endpoint: None
# 2022-11-04 23:47:08,476 ['jupyter', 'nbconvert', "-TagRemovePreprocessor.remove_input_tags='remove_input'", '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 384576 bytes to /opt/ml/processing/output/report.html
# 2022-11-04 23:47:09,449 ['wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2022-11-04 23:47:10,375 Collected analyses:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "Target",
#         "facets": {
#             "AGEGROUPS": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.06865542808186087
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.6377508229617606
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.022727272727272707
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": -23.90151515151515
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": 0.1902247820174386
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 0.04811979065710409
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.2530678502180509
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": 0.19845523469233567
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": -0.08742004264392324
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.2721554293096109
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.3638944753342009
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": 0.017094017094017144
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "Infinity"
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "4",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": 0.2082990904152331
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.1413365800865801
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": 0.9787234042553191
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": "-Infinity"
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.1641630037514692
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 0.0
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.13486370157819225
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.1608462541660629
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": -0.019417475728155338
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.2721554293096109
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.2902208201892745
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": 0.0052631578947368585
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "Infinity"
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "3",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": 0.16757394302304485
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.18091259695165945
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.021505376344086002
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": -62.70967741935484
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.1257484234981746
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 0.05441511893124797
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.13164579931046996
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.12227016262860946
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": -0.030303030303030304
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.2721554293096109
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.28223410576351754
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": 0.0055248618784530246
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "Infinity"
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "2",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.321774092222641
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": -0.20741071428571428
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": 0.04878048780487809
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": 5.331799355729406
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": 2.397163120567376
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 13.96136567834681
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.9062696318632993
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": 0.3971631205673759
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 0.9761904761904762
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.2721554293096109
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": -0.8408408408408409
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": -0.6666666666666667
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "-Infinity"
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "1",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.35741444866920147
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": -0.06535714285714285
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.02409638554216864
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": 3.3493975903614457
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.6062322946175638
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 9.506024096385541
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.8948035487959443
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.603399433427762
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 1.0
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.2721554293096109
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": -0.775623268698061
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": -0.9953271028037384
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": -140.0
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "5",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.17590857423735062
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": -0.19098214285714285
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.03389830508474578
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": 4.34769975786925
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.6131805157593123
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 10.443437130469057
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.7360142545543915
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.6103151862464183
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 0.7906976744186046
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.2721554293096109
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": -0.6407012087368347
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": -0.9953271028037384
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "Infinity"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     },
#     "pre_training_bias_metrics": {
#         "label": "Target",
#         "facets": {
#             "AGEGROUPS": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": 0.30756694763935616
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": -0.1725
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": 0.3096386861548966
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.04874965251217302
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.19906478519390636
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.3096386861548966
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.4378952293956411
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.3096386861548966
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "4",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.034542284722162774
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.7425
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.07917426975526176
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.003137961930925224
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.012557543737648502
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.07917426975526176
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.11196932607887713
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.07917426975526176
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "3",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.0067088919672761175
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.67
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.041916167664670656
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.0008802888890307708
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.003518057739403828
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.041916167664670656
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.059278412794081824
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.041916167664670656
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "2",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.08082199939288354
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.895
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.4892574444025632
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.15232073692563952
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.8264758040278647
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.4892574444025632
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.6919145133661053
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.48925744440256314
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "1",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.02125935421286031
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.9725
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.5424588086185045
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.05170723902953851
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": -0.3577461329115217
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.5424588086185045
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.5424588086185045
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.27122940430925224
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "5",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.10923441734417345
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.8925
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.5653896961690885
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.057245879396104496
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": -0.3621631577002818
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.5653896961690885
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.5653896961690885
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.28269484808454426
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }
# 2022-11-04 23:47:10,375 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ---!

# %%
bias_report_output_path
# Out:
# 's3://sagemaker-us-east-1-068232277654/chapter11/clarify-bias'

# %% [markdown]
# Similarly, we can run the SageMaker Clarify explainability report using SHAP configurations, as shown in the following code.

# %%
shap_config = clarify.SHAPConfig(
    baseline=[X_test.iloc[0].values.tolist()],
    num_samples=15,
    agg_method="mean_abs",
    save_local_shap_values=True,
)

explainability_output_path = "s3://{}/{}/clarify-explainability".format(bucket, prefix)
explainability_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=explainability_output_path,
    label="Target",
    headers=X_train.columns.to_list(),
    dataset_type="text/csv",
)

# %% [markdown]
# The following code runs the model explainability report using SageMaker Clarify.

# %%
clarify_processor.run_explainability(
    data_config=explainability_data_config,
    model_config=model_config,
    explainability_config=shap_config,
)
# Out:
# Job Name:  Clarify-Explainability-2022-11-04-23-47-59-831
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-068232277654/chapter11/train.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-068232277654/chapter11/clarify-explainability/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-us-east-1-068232277654/chapter11/clarify-explainability', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ................................2022-11-04 23:53:06,115 logging.conf not found when configuring logging, using default logging configuration.
# 2022-11-04 23:53:06,116 Starting SageMaker Clarify Processing job
# 2022-11-04 23:53:06,116 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-11-04 23:53:06,116 Analysis result path: /opt/ml/processing/output
# 2022-11-04 23:53:06,116 This host is algo-1.
# 2022-11-04 23:53:06,116 This host is the leader.
# 2022-11-04 23:53:06,116 Number of hosts in the cluster is 1.
# 2022-11-04 23:53:06,404 Running Python / Pandas based analyzer.
# 2022-11-04 23:53:06,405 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2022-11-04 23:53:06,409 Loading dataset...
# /usr/local/lib/python3.9/site-packages/analyzer/data_loading/csv_data_loader.py:311: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_tmp, ignore_index=True)
# 2022-11-04 23:53:06,417 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CITY       800 non-null    int64
#  1   COUNTY     800 non-null    int64
#  2   AGEGROUPS  800 non-null    int64
# dtypes: int64(3)
# memory usage: 18.9 KB
# 2022-11-04 23:53:06,470 Spinning up shadow endpoint
# 2022-11-04 23:53:06,470 Creating endpoint-config with name sm-clarify-config-1667605986-173f
# 2022-11-04 23:53:06,628 Creating endpoint: 'sm-clarify-xgb-model-04-11-2022-23-38-59-1667605986-8482'
# 2022-11-04 23:53:07,022 Using endpoint name: sm-clarify-xgb-model-04-11-2022-23-38-59-1667605986-8482
# 2022-11-04 23:53:07,022 Waiting for endpoint ...
# 2022-11-04 23:53:07,022 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-11-04 23:56:07,481 Endpoint is in service after 180 seconds
# 2022-11-04 23:56:07,481 Endpoint ready.
# 2022-11-04 23:56:07,483 SHAP n_samples 6
# 2022-11-04 23:56:07,595 =====================================================
# 2022-11-04 23:56:07,595 Shap analyzer: explaining 800 rows, 3 columns...
# 2022-11-04 23:56:07,595 =====================================================
#   0% (0 of 800) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (800 of 800) |######################| Elapsed Time: 0:00:07 Time:  0:00:07
# 2022-11-04 23:56:15,004 getting explanations took 7.41 seconds.
# 2022-11-04 23:56:15,005 ===================================================
# 2022-11-04 23:56:15,005 Falling back to generic labels: label0, label1, ...
# 2022-11-04 23:56:15,044 converting explanations to tabular took 0.04 seconds.
# 2022-11-04 23:56:15,045 ===================================================
# 2022-11-04 23:56:15,047 Wrote baseline used to compute explanations to: /opt/ml/processing/output/explanations_shap/baseline.csv
# 2022-11-04 23:56:15,051 Wrote 800 local explanations to: /opt/ml/processing/output/explanations_shap/out.csv
# 2022-11-04 23:56:15,051 writing local explanations took 0.01 seconds.
# 2022-11-04 23:56:15,051 ===================================================
# /usr/local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# 2022-11-04 23:56:15,053 aggregating local explanations took 0.00 seconds.
# 2022-11-04 23:56:15,053 ===================================================
# 2022-11-04 23:56:15,053 Shap analysis finished.
# 2022-11-04 23:56:15,053 Calculated global analysis with predictor
# 2022-11-04 23:56:15,053 Stop using endpoint: sm-clarify-xgb-model-04-11-2022-23-38-59-1667605986-8482
# 2022-11-04 23:56:15,053 Deleting endpoint configuration with name: sm-clarify-config-1667605986-173f
# 2022-11-04 23:56:15,222 Deleting endpoint with name: sm-clarify-xgb-model-04-11-2022-23-38-59-1667605986-8482
# 2022-11-04 23:56:15,323 Model endpoint delivered 105.91369 requests per second and a total of 802 requests over 8 seconds
# 2022-11-04 23:56:15,323 Calculated global analysis without predictor
# 2022-11-04 23:56:16,851 Stop using endpoint: None
# 2022-11-04 23:56:18,816 ['jupyter', 'nbconvert', "-TagRemovePreprocessor.remove_input_tags='remove_input'", '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 477097 bytes to /opt/ml/processing/output/report.html
# 2022-11-04 23:56:19,757 ['wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2022-11-04 23:56:20,290 Collected analyses:
# {
#     "version": "1.0",
#     "explanations": {
#         "kernel_shap": {
#             "label0": {
#                 "global_shap_values": {
#                     "CITY": 0.06291764706683654,
#                     "COUNTY": 0.1138087816753735,
#                     "AGEGROUPS": 0.13643475705447297
#                 },
#                 "expected_value": 0.6109660267829895
#             }
#         }
#     }
# }
# 2022-11-04 23:56:20,291 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ---!

# %% [markdown]
# Once you have generated the two reports, return to the subsection *Viewing the bias and explainability reports in SageMaker Studio* to learn how to visualize these reports on SageMaker Studio.
#
# You can delete the model created in this exercise by running the following line of code.

# %%
session.delete_model(model_name)
