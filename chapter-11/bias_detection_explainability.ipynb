# %% [markdown]
# ### Bias Detection and Explanability in Healthcare Coverage Amounts
# This exercise is part of Chapter 11 in the book Applied Machine Learning for Healthcare and Lifesciences on AWS. Make sure you have completed the steps as outlined in the Technical Requirements section of Chapter 11 to successfully complete this exercise. Also, make sure you have downloaded the dataset as created the data folder as described in Aquiring the Dataset sub section under Detecting bias and explaining model predictions for healthcare coverage amounts section.
# In this notebook we will use Sagemaker Clarify to create bias metrics for our training data and also our model. We will also generate explanability metrics for our model to gather feature importance for our model.
# Note: Parts of this notebook references the following link: https://sagemaker-examples.readthedocs.io/en/latest/sagemaker_processing/fairness_and_explainability/fairness_and_explainability.html

# %% [markdown]
# Lets start by importing the required libraries and setting some environment variables.

# %%
from sagemaker import Session
from sagemaker import get_execution_role
import pandas as pd
import numpy as np
import os
import boto3
from datetime import datetime

session = Session()
bucket = session.default_bucket()
prefix = "chapter11"
region = session.boto_region_name
role = get_execution_role()
s3_client = boto3.client("s3")

# %% [markdown]
# Next, we will read the patients.csv file into a dataframe and examine its contents.

# %%
raw_data=pd.read_csv('data/patients.csv')

# %%
raw_data.head()
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  1d604da9-9a81-4ba9-80c2-de3375d59b40  1989-05-25       NaN  999-76-6866
# 1  034e9e3b-2def-4559-bb2a-7850888ae060  1983-11-14       NaN  999-73-5361
# 2  10339b10-3cd1-4ac3-ac13-ec26728cb592  1992-06-02       NaN  999-27-3385
# 3  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  1978-05-27       NaN  999-85-4926
# 4  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a  1996-10-18       NaN  999-60-7372
#
#      DRIVERS    PASSPORT PREFIX            FIRST           LAST SUFFIX  ...  \
# 0  S99984236  X19277260X    Mr.  José Eduardo181       Gómez206    NaN  ...
# 1  S99962402  X88275464X    Mr.          Milo271        Feil794    NaN  ...
# 2  S99972682  X73754411X    Mr.        Jayson808       Fadel536    NaN  ...
# 3  S99974448  X40915583X   Mrs.       Mariana775  Rutherford999    NaN  ...
# 4  S99915787  X86772962X    Mr.      Gregorio366         Auer97    NaN  ...
#
#                          BIRTHPLACE                         ADDRESS  \
# 0  Marigot  Saint Andrew Parish  DM      427 Balistreri Way Unit 19
# 1        Danvers  Massachusetts  US        422 Farrell Path Unit 69
# 2    Springfield  Massachusetts  US       1056 Harris Lane Suite 70
# 3       Yarmouth  Massachusetts  US                  999 Kuhn Forge
# 4                Patras  Achaea  GR  1050 Lindgren Extension Apt 38
#
#          CITY          STATE            COUNTY     ZIP        LAT        LON  \
# 0    Chicopee  Massachusetts    Hampden County  1013.0  42.228354 -72.562951
# 1  Somerville  Massachusetts  Middlesex County  2143.0  42.360697 -71.126531
# 2    Chicopee  Massachusetts    Hampden County  1020.0  42.181642 -72.608842
# 3      Lowell  Massachusetts  Middlesex County  1851.0  42.636143 -71.343255
# 4      Boston  Massachusetts    Suffolk County  2135.0  42.352434 -71.028610
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE
# 0           271227.08             1334.88
# 1           793946.01             3204.49
# 2           574111.90             2606.40
# 3           935630.30             8756.19
# 4           598763.07             3772.20
#
# [5 rows x 25 columns]

# %% [markdown]
# We will now do some transformations to the data:
# 1. Use the BIRTHDATE column to calculate the age and categorize patients into different agegroups like Infant, Toddler, Kid, Teen, Adult and Old.
# 2. Calculate COVERAGETOEXPENSERATIO by dividing HEALTHCARE_COVERAGE by HEALTHCARE_EXPENSES
# 3. Create a new binary TARGET variable that has the value False if the COVERAGETOEXPENSERATIO is <=0.01, else it is True.
#
# Essentialy, we want to find patients who have less than one percent coeverage for their healthcare expenses.

# %%
def calculateage(dob):
    today = date.today()
    return today.year - dob.year - ((today.month, 
                                      today.day) < (dob.month, 
                                                    dob.day))

# %%
raw_data['BIRTHDATE'] = pd.to_datetime(raw_data['BIRTHDATE'])
raw_data=raw_data[raw_data['DEATHDATE'].isna()]
raw_data['AGE'] = raw_data['BIRTHDATE'].apply(calculateage)
raw_data['COVERAGETOEXPENSERATIO'] = raw_data['HEALTHCARE_COVERAGE']/raw_data['HEALTHCARE_EXPENSES']
labels = ['Infant','Toddler','Kid','Teen', 'Adult', 'Old']
raw_data['AGEGROUPS'] = pd.cut(raw_data['AGE'], labels=labels, bins=[0, 3, 7, 12, 21, 65, np.inf])
raw_data['Target'] = raw_data['COVERAGETOEXPENSERATIO'].apply(lambda x: 'False' if x <= 0.01 else 'True')

# %% [markdown]
# Next, we sellect CITY, COUNTY and AGEGROUPS columns as our features and TARGET column as our target. Since the TARGET has True and False values, we model this as a binary classification problem.

# %%
X=raw_data[['CITY','COUNTY','AGEGROUPS']]
y=raw_data[['Target']]

# %% [markdown]
# We can now divide our patient population into train and test. We will use Label Encoder to encode our categorical columns into numerical values.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn import preprocessing
enc = preprocessing.LabelEncoder()
X_train=X_train.apply(enc.fit_transform)
X_test=X_test.apply(enc.fit_transform)
y_train=y_train.apply(enc.fit_transform)
y_test=y_test.apply(enc.fit_transform)

# %% [markdown]
# To train a model on Sagemaker, we need to have the first column of our training data as the target variable. The same needs to be removed from the test dataset. We do this in the next section and save the files as CSVs.

# %%
X_train.insert(0, 'Target', y_train['Target'])
X_train.to_csv("data/train.csv", index=False, header=False)

# %%
X_test.to_csv("data/test.csv", index=False, header=False)

# %% [markdown]
# Next, lets upload the files on S3 as shown below.

# %%
from sagemaker.s3 import S3Uploader
from sagemaker.inputs import TrainingInput

train_uri = S3Uploader.upload("data/train.csv", "s3://{}/{}".format(bucket, prefix))
train_input = TrainingInput(train_uri, content_type="csv")
test_uri = S3Uploader.upload("data/test.csv", "s3://{}/{}".format(bucket, prefix))

# %% [markdown]
# We are now ready to run our model training on Sagemaker. We choose the Sagemaker xgboost container to run our training.

# %%
from sagemaker.image_uris import retrieve
from sagemaker.estimator import Estimator

container = retrieve("xgboost", region, version="1.2-1")
xgb = Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    disable_profiler=True,
    sagemaker_session=session,
)

xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    objective="binary:logistic",
    num_round=800,
)

xgb.fit({"train": train_input}, logs=False)
# Out:
# 2022-09-08 04:16:53 Starting - Starting the training job.....
# 2022-09-08 04:17:23 Starting - Preparing the instances for training...........
# 2022-09-08 04:18:20 Downloading - Downloading input data......
# 2022-09-08 04:18:55 Training - Downloading the training image..........
# 2022-09-08 04:19:51 Training - Training image download completed. Training in progress...
# 2022-09-08 04:20:06 Uploading - Uploading generated training model.
# 2022-09-08 04:20:17 Completed - Training job completed

# %% [markdown]
# Once, the training completes, we can create a model artifact from the estimator used in the training job.

# %%
model_name = "xgb-model-{}".format(datetime.now().strftime("%d-%m-%Y-%H-%M-%S"))
model = xgb.create_model(name=model_name)
container_def = model.prepare_container_def()
session.create_model(model_name, role, container_def)
# Out:
# 'xgb-model-21-09-2022-21-36-26'

# %% [markdown]
# We now have all the prerequisits for running Sagemaker Clarify. We bigin by defining a Sagemaker Clarify processor.

# %%
from sagemaker import clarify

clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role, instance_count=1, instance_type="ml.m5.xlarge", sagemaker_session=session
)

# %% [markdown]
# Next, we define configurations for our data and model bias metrics.

# %%
bias_report_output_path = "s3://{}/{}/clarify-bias".format(bucket, prefix)
bias_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=bias_report_output_path,
    label="Target",
    headers=X_train.columns.to_list(),
    dataset_type="text/csv",
)

# %%
model_config = clarify.ModelConfig(
    model_name=model_name,
    instance_type="ml.m5.xlarge",
    instance_count=1,
    accept_type="text/csv",
    content_type="text/csv",
)

# %% [markdown]
# We try to create a bias report for our feature AGEGROUP and try and analyze the bias that feature has in each CITY. We also define a prediction probability threshold for our model predictions.

# %%
predictions_config = clarify.ModelPredictedLabelConfig(probability_threshold=0.8)

# %%
bias_config = clarify.BiasConfig(
    label_values_or_threshold=[1], facet_name="AGEGROUPS", group_name="CITY"
)

# %% [markdown]
# The following code runs the Sagemaker Clarify Bias report processor.

# %%
clarify_processor.run_bias(
    data_config=bias_data_config,
    bias_config=bias_config,
    model_config=model_config,
    model_predicted_label_config=predictions_config,
    pre_training_methods="all",
    post_training_methods="all",
)
# Out:
# Job Name:  Clarify-Bias-2022-09-09-03-36-49-713
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-485822383573/chapter11/train.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-485822383573/chapter11/clarify-bias/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-us-east-1-485822383573/chapter11/clarify-bias', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ..........................................................................2022-09-09 03:48:59,389 logging.conf not found when configuring logging, using default logging configuration.
# 2022-09-09 03:48:59,390 Starting SageMaker Clarify Processing job
# 2022-09-09 03:48:59,390 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-09-09 03:48:59,390 Analysis result path: /opt/ml/processing/output
# 2022-09-09 03:48:59,390 This host is algo-1.
# 2022-09-09 03:48:59,390 This host is the leader.
# 2022-09-09 03:48:59,390 Number of hosts in the cluster is 1.
# 2022-09-09 03:48:59,663 Running Python / Pandas based analyzer.
# 2022-09-09 03:48:59,663 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2022-09-09 03:48:59,667 Loading dataset...
# /usr/local/lib/python3.9/site-packages/analyzer/data_loading/csv_data_loader.py:408: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_tmp, ignore_index=True)
# 2022-09-09 03:48:59,675 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CITY       800 non-null    int64
#  1   COUNTY     800 non-null    int64
#  2   AGEGROUPS  800 non-null    int64
# dtypes: int64(3)
# memory usage: 18.9 KB
# 2022-09-09 03:48:59,730 Spinning up shadow endpoint
# 2022-09-09 03:48:59,730 Creating endpoint-config with name sm-clarify-config-1662695339-f50d
# 2022-09-09 03:48:59,818 Creating endpoint: 'sm-clarify-xgb-model-08-09-2022-04-28-58-1662695339-202e'
# 2022-09-09 03:49:00,224 Using endpoint name: sm-clarify-xgb-model-08-09-2022-04-28-58-1662695339-202e
# 2022-09-09 03:49:00,224 Waiting for endpoint ...
# 2022-09-09 03:49:00,225 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-09-09 03:52:00,741 Endpoint is in service after 181 seconds
# 2022-09-09 03:52:00,742 Endpoint ready.
# 2022-09-09 03:52:00,742 ======================================
# 2022-09-09 03:52:00,742 Calculating post-training bias metrics
# 2022-09-09 03:52:00,742 ======================================
# 2022-09-09 03:52:00,742 Getting predictions from the endpoint
# 2022-09-09 03:52:00,996 We assume a prediction above 0.800 indicates 1 and below or equal indicates 0.
# 2022-09-09 03:52:00,997 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-09-09 03:52:00,999 Column AGEGROUPS with data uniqueness fraction 0.0075 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:456: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2022-09-09 03:52:01,000 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-09-09 03:52:01,001 Column None with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-09-09 03:52:02,869 Stop using endpoint: sm-clarify-xgb-model-08-09-2022-04-28-58-1662695339-202e
# 2022-09-09 03:52:02,870 Deleting endpoint configuration with name: sm-clarify-config-1662695339-f50d
# 2022-09-09 03:52:02,971 Deleting endpoint with name: sm-clarify-xgb-model-08-09-2022-04-28-58-1662695339-202e
# 2022-09-09 03:52:03,080 Model endpoint delivered 0.93986 requests per second and a total of 2 requests over 2 seconds
# 2022-09-09 03:52:03,080 Stop using endpoint: None
# 2022-09-09 03:52:03,080 =====================================
# 2022-09-09 03:52:03,080 Calculating pre-training bias metrics
# 2022-09-09 03:52:03,080 =====================================
# 2022-09-09 03:52:03,081 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-09-09 03:52:03,082 Column AGEGROUPS with data uniqueness fraction 0.0075 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:456: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2022-09-09 03:52:03,084 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-09-09 03:52:04,759 ======================================
# 2022-09-09 03:52:04,759 Calculating bias statistics for report
# 2022-09-09 03:52:04,759 ======================================
# 2022-09-09 03:52:04,759 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-09-09 03:52:04,761 Column AGEGROUPS with data uniqueness fraction 0.0075 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:456: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2022-09-09 03:52:04,762 Column Target with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-09-09 03:52:04,763 Column None with data uniqueness fraction 0.0025 is classifed as a CATEGORICAL column
# 2022-09-09 03:52:04,773 Stop using endpoint: None
# 2022-09-09 03:52:05,191 ['jupyter', 'nbconvert', "-TagRemovePreprocessor.remove_input_tags='remove_input'", '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 383427 bytes to /opt/ml/processing/output/report.html
# 2022-09-09 03:52:06,149 ['/usr/local/bin/wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2022-09-09 03:52:06,980 Collected analyses:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "Target",
#         "facets": {
#             "AGEGROUPS": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.05315977487085921
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.6526578742438117
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": 0.9560439560439561
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": "-Infinity"
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": 0.1671170455147566
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 0.0
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.27245508982035926
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": 0.1835779508645508
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": -0.09871244635193133
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.40654205607476634
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "Infinity"
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "4",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": 0.19263925729442977
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.1423100233100233
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": 0.9560439560439561
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": "-Infinity"
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.15529243483788935
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 0.0
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.1307471264367816
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.14868086458995555
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": -0.019230769230769232
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.2744479495268139
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "Infinity"
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "3",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": 0.1522267483654538
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.17753210244616494
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.0444444444444444
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": -61.58888888888889
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.1175235817722865
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 0.05674300254452926
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.12689556019580323
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.11061511890527442
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": -0.03816793893129771
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.26474567777499375
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "Infinity"
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "2",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.23797498797498795
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": -0.20466071428571425
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": 0.09756097560975607
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": 5.708780487804878
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": 1.0675165250236072
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 14.08909090909091
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.8656806156806156
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.26581680830972615
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 0.9318181818181818
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": -0.7985677985677986
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "-Infinity"
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "1",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.366751269035533
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": -0.06852380952380951
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.05063291139240511
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": 3.556962025316456
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.6036671368124118
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 9.974683544303797
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.899746192893401
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.5980253878702397
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 1.0
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": -0.7916666666666666
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": -71.25
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "5",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.2343092378114343
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": -0.20056547619047616
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.07407407407407407
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": 4.93043043043043
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.6088193456614509
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 12.06244616709733
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.7891309022764277
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.6031294452347084
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 0.8604651162790697
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": -0.7084894323884923
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "Infinity"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     },
#     "pre_training_bias_metrics": {
#         "label": "Target",
#         "facets": {
#             "AGEGROUPS": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": 0.3035565309726895
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": -0.165
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": 0.3016627688828352
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.04623720690322153
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.1887648966097895
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.3016627688828352
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.42661557901712605
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.3016627688828352
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "4",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.03333016351004156
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.74
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.07338638373121131
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.0026958699026190143
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.010784875793614979
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.07338638373121131
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.1037840191661953
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.07338638373121131
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "3",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.004990141967276116
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.6725
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.03728933465694495
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.0006968163098004989
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.002784794789921767
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.03728933465694506
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.05273508280372071
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.037289334656945006
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "2",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.07849245393833808
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.89
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.4458874458874459
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.11869330692906874
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.5839149452774408
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.4458874458874459
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.6305800732659255
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.4458874458874459
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "1",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.023290604212860312
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.97
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.5431472081218274
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.05186763905786965
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": -0.35789576272434065
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.5431472081218274
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.5431472081218274
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.2715736040609137
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "5",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.10845316734417346
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.8925
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.5653896961690885
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.057245879396104524
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": -0.3621631577002818
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.5653896961690885
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.5653896961690885
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.28269484808454426
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }
# 2022-09-09 03:52:06,981 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ---!

# %%
bias_report_output_path
# Out:
# 's3://sagemaker-us-east-1-485822383573/chapter11/clarify-bias'

# %% [markdown]
# Similarly, we can run the Sagemaker Clarify explainability report using SHAP configurations as shown below.

# %%
shap_config = clarify.SHAPConfig(
    baseline=[X_test.iloc[0].values.tolist()],
    num_samples=15,
    agg_method="mean_abs",
    save_local_shap_values=True,
)

explainability_output_path = "s3://{}/{}/clarify-explainability".format(bucket, prefix)
explainability_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=explainability_output_path,
    label="Target",
    headers=X_train.columns.to_list(),
    dataset_type="text/csv",
)

# %% [markdown]
# The following code runs the model explainability report using Sagemaker Clarify.

# %%
clarify_processor.run_explainability(
    data_config=explainability_data_config,
    model_config=model_config,
    explainability_config=shap_config,
)
# Out:
# Job Name:  Clarify-Explainability-2022-09-09-04-12-46-300
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-485822383573/chapter11/train.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-485822383573/chapter11/clarify-explainability/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-us-east-1-485822383573/chapter11/clarify-explainability', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ............................................2022-09-09 04:19:58,350 logging.conf not found when configuring logging, using default logging configuration.
# 2022-09-09 04:19:58,350 Starting SageMaker Clarify Processing job
# 2022-09-09 04:19:58,351 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-09-09 04:19:58,351 Analysis result path: /opt/ml/processing/output
# 2022-09-09 04:19:58,351 This host is algo-1.
# 2022-09-09 04:19:58,351 This host is the leader.
# 2022-09-09 04:19:58,351 Number of hosts in the cluster is 1.
# 2022-09-09 04:19:58,629 Running Python / Pandas based analyzer.
# 2022-09-09 04:19:58,629 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2022-09-09 04:19:58,633 Loading dataset...
# /usr/local/lib/python3.9/site-packages/analyzer/data_loading/csv_data_loader.py:408: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_tmp, ignore_index=True)
# 2022-09-09 04:19:58,642 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CITY       800 non-null    int64
#  1   COUNTY     800 non-null    int64
#  2   AGEGROUPS  800 non-null    int64
# dtypes: int64(3)
# memory usage: 18.9 KB
# 2022-09-09 04:19:58,696 Spinning up shadow endpoint
# 2022-09-09 04:19:58,696 Creating endpoint-config with name sm-clarify-config-1662697198-d330
# 2022-09-09 04:19:58,791 Creating endpoint: 'sm-clarify-xgb-model-08-09-2022-04-28-58-1662697198-7e95'
# 2022-09-09 04:19:59,078 Using endpoint name: sm-clarify-xgb-model-08-09-2022-04-28-58-1662697198-7e95
# 2022-09-09 04:19:59,078 Waiting for endpoint ...
# 2022-09-09 04:19:59,078 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-09-09 04:22:59,592 Endpoint is in service after 181 seconds
# 2022-09-09 04:22:59,592 Endpoint ready.
# 2022-09-09 04:22:59,593 SHAP n_samples 6
# 2022-09-09 04:22:59,694 =====================================================
# 2022-09-09 04:22:59,694 Shap analyzer: explaining 800 rows, 3 columns...
# 2022-09-09 04:22:59,694 =====================================================
#   0% (0 of 800) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (800 of 800) |######################| Elapsed Time: 0:00:06 Time:  0:00:06
# 2022-09-09 04:23:06,140 getting explanations took 6.45 seconds.
# 2022-09-09 04:23:06,141 ===================================================
# 2022-09-09 04:23:06,141 Falling back to generic labels: label0, label1, ...
# 2022-09-09 04:23:06,181 converting explanations to tabular took 0.04 seconds.
# 2022-09-09 04:23:06,181 ===================================================
# 2022-09-09 04:23:06,183 Wrote baseline used to compute explanations to: /opt/ml/processing/output/explanations_shap/baseline.csv
# 2022-09-09 04:23:06,187 Wrote 800 local explanations to: /opt/ml/processing/output/explanations_shap/out.csv
# 2022-09-09 04:23:06,187 writing local explanations took 0.01 seconds.
# 2022-09-09 04:23:06,188 ===================================================
# /usr/local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# 2022-09-09 04:23:06,190 aggregating local explanations took 0.00 seconds.
# 2022-09-09 04:23:06,190 ===================================================
# 2022-09-09 04:23:06,190 Shap analysis finished.
# 2022-09-09 04:23:06,190 Stop using endpoint: sm-clarify-xgb-model-08-09-2022-04-28-58-1662697198-7e95
# 2022-09-09 04:23:06,190 Deleting endpoint configuration with name: sm-clarify-config-1662697198-d330
# 2022-09-09 04:23:06,331 Deleting endpoint with name: sm-clarify-xgb-model-08-09-2022-04-28-58-1662697198-7e95
# 2022-09-09 04:23:06,448 Model endpoint delivered 121.55495 requests per second and a total of 802 requests over 7 seconds
# 2022-09-09 04:23:06,454 Stop using endpoint: None
# 2022-09-09 04:23:09,873 ['jupyter', 'nbconvert', "-TagRemovePreprocessor.remove_input_tags='remove_input'", '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
#
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 475848 bytes to /opt/ml/processing/output/report.html
# 2022-09-09 04:23:10,916 ['/usr/local/bin/wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2022-09-09 04:23:11,433 Collected analyses:
# {
#     "version": "1.0",
#     "explanations": {
#         "kernel_shap": {
#             "label0": {
#                 "global_shap_values": {
#                     "CITY": 0.058407376228521254,
#                     "COUNTY": 0.09340313097462058,
#                     "AGEGROUPS": 0.13892449465890727
#                 },
#                 "expected_value": 0.6054581999778748
#             }
#         }
#     }
# }
# 2022-09-09 04:23:11,434 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ---!

# %% [markdown]
# Once you have generated the two reports, return to the sub section Viewing the bias and explainability reports in Sagemaker Studio to visulize these reports on Sagemaker Studio.
#
# You can delete the model created in this exercise by running the code below.

# %%
session.delete_model(model_name)
